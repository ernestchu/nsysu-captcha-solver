# %%
import cv2
import csv
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

encoding = '123456789'
labels_file = 'labels.csv'

img_list = []
label_list = []

with open(labels_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    fieldnames = reader.fieldnames
    for row in reader:
        img_list.append(row[fieldnames[0]])
        label_list.append(encoding.index(row[fieldnames[1]]))
    
items=[]
for i in range(len(img_list)):
    items.append(i)
X = []
y = []
for i in random.sample(items,len(img_list)):
    img = cv2.imread(img_list[i], 0)
    img = tf.keras.preprocessing.image.img_to_array(img)
    X.append(img)
    y.append(label_list[i])
    
X = 1 - np.array(X).astype(float)/255 # invert and scale
y = np.array(y).astype(float)

plt.imshow(X[0], cmap=plt.get_cmap('gray'))
print(y[0])
# Out:
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-a3a49c1ef03d> in <module>
#      28     img = tf.keras.preprocessing.image.img_to_array(img)
#      29     print(type(img))
# ---> 30     assert False
#      31     X.append(img)
#      32     y.append(label_list[i])
#
# AssertionError:

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(24, 31, 1)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Dropout(rate=0.25))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(9, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 29, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 27, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 13, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 13, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8320)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1065088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 1,085,065
# Trainable params: 1,085,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
initial_learning_rate = 1e-2
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True
)
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule), 
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
)
batch_size = 32
epochs = 80

# %%
history = model.fit(
    X, 
    y,
    batch_size = batch_size,
    epochs = epochs,
    validation_split = 0.2,
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]
)
# Out:
# Epoch 1/80
# 29/29 [==============================] - 1s 28ms/step - loss: 2.5672 - sparse_categorical_accuracy: 0.1266 - val_loss: 1.9830 - val_sparse_categorical_accuracy: 0.2356
# Epoch 2/80
# 29/29 [==============================] - 0s 11ms/step - loss: 1.6944 - sparse_categorical_accuracy: 0.4016 - val_loss: 1.0720 - val_sparse_categorical_accuracy: 0.7067
# Epoch 3/80
# 29/29 [==============================] - 0s 11ms/step - loss: 1.0234 - sparse_categorical_accuracy: 0.6663 - val_loss: 0.6794 - val_sparse_categorical_accuracy: 0.7911
# Epoch 4/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.7198 - sparse_categorical_accuracy: 0.7946 - val_loss: 0.4916 - val_sparse_categorical_accuracy: 0.8578
# Epoch 5/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.5959 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.3782 - val_sparse_categorical_accuracy: 0.8844
# Epoch 6/80
# 29/29 [==============================] - 0s 10ms/step - loss: 0.4787 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.3479 - val_sparse_categorical_accuracy: 0.8889
# Epoch 7/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.4078 - sparse_categorical_accuracy: 0.8763 - val_loss: 0.2610 - val_sparse_categorical_accuracy: 0.9244
# Epoch 8/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3591 - sparse_categorical_accuracy: 0.8725 - val_loss: 0.2855 - val_sparse_categorical_accuracy: 0.8800
# Epoch 9/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3229 - sparse_categorical_accuracy: 0.9014 - val_loss: 0.1856 - val_sparse_categorical_accuracy: 0.9467
# Epoch 10/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3352 - sparse_categorical_accuracy: 0.8773 - val_loss: 0.2415 - val_sparse_categorical_accuracy: 0.9289
# Epoch 11/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2696 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.1721 - val_sparse_categorical_accuracy: 0.9467
# Epoch 12/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2409 - sparse_categorical_accuracy: 0.9245 - val_loss: 0.1678 - val_sparse_categorical_accuracy: 0.9689
# Epoch 13/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2551 - sparse_categorical_accuracy: 0.8974 - val_loss: 0.2301 - val_sparse_categorical_accuracy: 0.9333
# Epoch 14/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3062 - sparse_categorical_accuracy: 0.9020 - val_loss: 0.1807 - val_sparse_categorical_accuracy: 0.9511
# Epoch 15/80
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2343 - sparse_categorical_accuracy: 0.9033 - val_loss: 0.1493 - val_sparse_categorical_accuracy: 0.9556
# Epoch 16/80
# 29/29 [==============================] - 0s 12ms/step - loss: 0.2336 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.1546 - val_sparse_categorical_accuracy: 0.9600
# Epoch 17/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2982 - sparse_categorical_accuracy: 0.8911 - val_loss: 0.1959 - val_sparse_categorical_accuracy: 0.9467
# Epoch 18/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.3029 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.1141 - val_sparse_categorical_accuracy: 0.9689
# Epoch 19/80
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2387 - sparse_categorical_accuracy: 0.9120 - val_loss: 0.1487 - val_sparse_categorical_accuracy: 0.9644
# Epoch 20/80
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2490 - sparse_categorical_accuracy: 0.9218 - val_loss: 0.1555 - val_sparse_categorical_accuracy: 0.9467
# Epoch 21/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2282 - sparse_categorical_accuracy: 0.9304 - val_loss: 0.1304 - val_sparse_categorical_accuracy: 0.9556
# Epoch 22/80
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1999 - sparse_categorical_accuracy: 0.9334 - val_loss: 0.1453 - val_sparse_categorical_accuracy: 0.9644
# Epoch 23/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1734 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.0832 - val_sparse_categorical_accuracy: 0.9778
# Epoch 24/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1646 - sparse_categorical_accuracy: 0.9454 - val_loss: 0.1059 - val_sparse_categorical_accuracy: 0.9778
# Epoch 25/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1901 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.1139 - val_sparse_categorical_accuracy: 0.9733
# Epoch 26/80
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.1130 - val_sparse_categorical_accuracy: 0.9689
# Epoch 27/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2714 - sparse_categorical_accuracy: 0.9126 - val_loss: 0.1314 - val_sparse_categorical_accuracy: 0.9689
# Epoch 28/80
# 29/29 [==============================] - 0s 13ms/step - loss: 0.1781 - sparse_categorical_accuracy: 0.9277 - val_loss: 0.1596 - val_sparse_categorical_accuracy: 0.9467
# Epoch 29/80
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1360 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.1384 - val_sparse_categorical_accuracy: 0.9511
# Epoch 30/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.2062 - sparse_categorical_accuracy: 0.9385 - val_loss: 0.0816 - val_sparse_categorical_accuracy: 0.9733
# Epoch 31/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1265 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.1210 - val_sparse_categorical_accuracy: 0.9600
# Epoch 32/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1550 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.1153 - val_sparse_categorical_accuracy: 0.9689
# Epoch 33/80
# 29/29 [==============================] - 0s 12ms/step - loss: 0.1040 - sparse_categorical_accuracy: 0.9582 - val_loss: 0.0857 - val_sparse_categorical_accuracy: 0.9689
# Epoch 34/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1569 - sparse_categorical_accuracy: 0.9530 - val_loss: 0.1070 - val_sparse_categorical_accuracy: 0.9733
# Epoch 35/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1648 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.1174 - val_sparse_categorical_accuracy: 0.9733
# Epoch 36/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1644 - sparse_categorical_accuracy: 0.9482 - val_loss: 0.0922 - val_sparse_categorical_accuracy: 0.9689
# Epoch 37/80
# 29/29 [==============================] - 0s 14ms/step - loss: 0.4011 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.0831 - val_sparse_categorical_accuracy: 0.9778
# Epoch 38/80
# 29/29 [==============================] - 0s 10ms/step - loss: 0.1957 - sparse_categorical_accuracy: 0.9330 - val_loss: 0.0827 - val_sparse_categorical_accuracy: 0.9733
# Epoch 39/80
# 29/29 [==============================] - 0s 10ms/step - loss: 0.2360 - sparse_categorical_accuracy: 0.9336 - val_loss: 0.1223 - val_sparse_categorical_accuracy: 0.9733
# Epoch 40/80
# 29/29 [==============================] - 0s 11ms/step - loss: 0.1576 - sparse_categorical_accuracy: 0.9483 - val_loss: 0.0971 - val_sparse_categorical_accuracy: 0.9600

# %%
import pandas as pd
def plot_learning_curves(history):
    df = pd.DataFrame(history.history)
    df.plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
    
plot_learning_curves(history)

# %%
out = model.predict(np.expand_dims(X[5], 0))
plt.imshow(X[5], cmap=plt.get_cmap('gray'))
out
# Out:
# array([[1.3079872e-16, 1.5761232e-14, 5.2799631e-12, 1.4962311e-17,
#         2.1451520e-15, 4.0767113e-19, 1.0000000e+00, 5.1639794e-17,
#         1.8099850e-12]], dtype=float32)

# %%
model.save('model.h5')
