# %%
import cv2
import csv
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

encoding = '123456789'
labels_file = 'labels.csv'

img_list = []
label_list = []

with open(labels_file, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    fieldnames = reader.fieldnames
    for row in reader:
        img_list.append(row[fieldnames[0]])
        label_list.append(encoding.index(row[fieldnames[1]]))
    
items=[]
for i in range(len(img_list)):
    items.append(i)
X = []
y = []
for i in random.sample(items,len(img_list)):
    img = cv2.imread(img_list[i], 0)
    img = tf.keras.preprocessing.image.img_to_array(img)
    X.append(img)
    y.append(label_list[i])
    
X = 1 - np.array(X).astype(float)/255 # invert and scale
y = np.array(y).astype(float)

plt.imshow(X[0], cmap=plt.get_cmap('gray'))
print(y[0])
# Out:
# 6.0

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(24, 31, 1)))
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.Dropout(rate=0.25))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(9, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 29, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 27, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 13, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 13, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8320)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1065088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 1161
# =================================================================
# Total params: 1,085,065
# Trainable params: 1,085,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
initial_learning_rate = 1e-2
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True
)
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule), 
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()]
)
batch_size = 32
epochs = 80

# %%
history = model.fit(
    X, 
    y,
    batch_size = batch_size,
    epochs = epochs,
    validation_split = 0.2,
    callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)]
)
# Out:
# Epoch 1/80
# 47/47 [==============================] - 1s 20ms/step - loss: 2.2880 - sparse_categorical_accuracy: 0.1661 - val_loss: 1.0509 - val_sparse_categorical_accuracy: 0.7467
# Epoch 2/80
# 47/47 [==============================] - 0s 11ms/step - loss: 1.1950 - sparse_categorical_accuracy: 0.6288 - val_loss: 0.4523 - val_sparse_categorical_accuracy: 0.8853
# Epoch 3/80
# 47/47 [==============================] - 0s 11ms/step - loss: 0.6485 - sparse_categorical_accuracy: 0.7944 - val_loss: 0.3019 - val_sparse_categorical_accuracy: 0.9387
# Epoch 4/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4843 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.2497 - val_sparse_categorical_accuracy: 0.9333
# Epoch 5/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3998 - sparse_categorical_accuracy: 0.8611 - val_loss: 0.1615 - val_sparse_categorical_accuracy: 0.9627
# Epoch 6/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3810 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.0989 - val_sparse_categorical_accuracy: 0.9707
# Epoch 7/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.3240 - sparse_categorical_accuracy: 0.8992 - val_loss: 0.0970 - val_sparse_categorical_accuracy: 0.9787
# Epoch 8/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2525 - sparse_categorical_accuracy: 0.9184 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9893
# Epoch 9/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2391 - sparse_categorical_accuracy: 0.9341 - val_loss: 0.0847 - val_sparse_categorical_accuracy: 0.9813
# Epoch 10/80
# 47/47 [==============================] - 1s 11ms/step - loss: 0.2202 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.0798 - val_sparse_categorical_accuracy: 0.9733
# Epoch 11/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2132 - sparse_categorical_accuracy: 0.9252 - val_loss: 0.0625 - val_sparse_categorical_accuracy: 0.9813
# Epoch 12/80
# 47/47 [==============================] - 0s 11ms/step - loss: 0.2474 - sparse_categorical_accuracy: 0.9183 - val_loss: 0.0619 - val_sparse_categorical_accuracy: 0.9840
# Epoch 13/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2012 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.0719 - val_sparse_categorical_accuracy: 0.9840
# Epoch 14/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1838 - sparse_categorical_accuracy: 0.9413 - val_loss: 0.0630 - val_sparse_categorical_accuracy: 0.9840
# Epoch 15/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.0715 - val_sparse_categorical_accuracy: 0.9813
# Epoch 16/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1725 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.0592 - val_sparse_categorical_accuracy: 0.9840
# Epoch 17/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1663 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.0460 - val_sparse_categorical_accuracy: 0.9867
# Epoch 18/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1593 - sparse_categorical_accuracy: 0.9479 - val_loss: 0.0668 - val_sparse_categorical_accuracy: 0.9760
# Epoch 19/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1850 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.0422 - val_sparse_categorical_accuracy: 0.9893
# Epoch 20/80
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1721 - sparse_categorical_accuracy: 0.9486 - val_loss: 0.0755 - val_sparse_categorical_accuracy: 0.9733
# Epoch 21/80
# 47/47 [==============================] - 1s 11ms/step - loss: 0.1811 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.0331 - val_sparse_categorical_accuracy: 0.9920
# Epoch 22/80
# 47/47 [==============================] - 0s 11ms/step - loss: 0.1173 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.0324 - val_sparse_categorical_accuracy: 0.9867
# Epoch 23/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9562 - val_loss: 0.0375 - val_sparse_categorical_accuracy: 0.9893
# Epoch 24/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1123 - sparse_categorical_accuracy: 0.9610 - val_loss: 0.0505 - val_sparse_categorical_accuracy: 0.9840
# Epoch 25/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1354 - sparse_categorical_accuracy: 0.9545 - val_loss: 0.0417 - val_sparse_categorical_accuracy: 0.9920
# Epoch 26/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1266 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.0280 - val_sparse_categorical_accuracy: 0.9893
# Epoch 27/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0650 - sparse_categorical_accuracy: 0.9752 - val_loss: 0.0804 - val_sparse_categorical_accuracy: 0.9760
# Epoch 28/80
# 47/47 [==============================] - 0s 11ms/step - loss: 0.1519 - sparse_categorical_accuracy: 0.9540 - val_loss: 0.0367 - val_sparse_categorical_accuracy: 0.9920
# Epoch 29/80
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1861 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 0.9947
# Epoch 30/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.0264 - val_sparse_categorical_accuracy: 0.9947
# Epoch 31/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1931 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.0229 - val_sparse_categorical_accuracy: 0.9947
# Epoch 32/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1145 - sparse_categorical_accuracy: 0.9543 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9920
# Epoch 33/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1170 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.0308 - val_sparse_categorical_accuracy: 0.9840
# Epoch 34/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1452 - sparse_categorical_accuracy: 0.9522 - val_loss: 0.0253 - val_sparse_categorical_accuracy: 0.9893
# Epoch 35/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1649 - sparse_categorical_accuracy: 0.9440 - val_loss: 0.0270 - val_sparse_categorical_accuracy: 0.9867
# Epoch 36/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1383 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 0.9973
# Epoch 37/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1469 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.0332 - val_sparse_categorical_accuracy: 0.9893
# Epoch 38/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1328 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.0431 - val_sparse_categorical_accuracy: 0.9813
# Epoch 39/80
# 47/47 [==============================] - 0s 11ms/step - loss: 0.1254 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.0164 - val_sparse_categorical_accuracy: 0.9973
# Epoch 40/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1072 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.0150 - val_sparse_categorical_accuracy: 0.9947
# Epoch 41/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0855 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 0.9973
# Epoch 42/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0887 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.0154 - val_sparse_categorical_accuracy: 0.9947
# Epoch 43/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0913 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.0284 - val_sparse_categorical_accuracy: 0.9920
# Epoch 44/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1084 - sparse_categorical_accuracy: 0.9542 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9893
# Epoch 45/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1021 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9947
# Epoch 46/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1315 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.0458 - val_sparse_categorical_accuracy: 0.9867
# Epoch 47/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0980 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.0175 - val_sparse_categorical_accuracy: 0.9920
# Epoch 48/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1591 - sparse_categorical_accuracy: 0.9495 - val_loss: 0.0742 - val_sparse_categorical_accuracy: 0.9760
# Epoch 49/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1815 - sparse_categorical_accuracy: 0.9473 - val_loss: 0.0137 - val_sparse_categorical_accuracy: 0.9973
# Epoch 50/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0993 - sparse_categorical_accuracy: 0.9644 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 0.9947
# Epoch 51/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1266 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.0232 - val_sparse_categorical_accuracy: 0.9893
# Epoch 52/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1082 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9973
# Epoch 53/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1095 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.0188 - val_sparse_categorical_accuracy: 0.9920
# Epoch 54/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0992 - sparse_categorical_accuracy: 0.9654 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 0.9920
# Epoch 55/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1160 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.0242 - val_sparse_categorical_accuracy: 0.9893
# Epoch 56/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1052 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 0.9973
# Epoch 57/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0704 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.0147 - val_sparse_categorical_accuracy: 0.9973
# Epoch 58/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9721 - val_loss: 0.0192 - val_sparse_categorical_accuracy: 0.9893
# Epoch 59/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9741 - val_loss: 0.0132 - val_sparse_categorical_accuracy: 0.9947
# Epoch 60/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0736 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.0193 - val_sparse_categorical_accuracy: 0.9973
# Epoch 61/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 0.9947
# Epoch 62/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0755 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.0273 - val_sparse_categorical_accuracy: 0.9920
# Epoch 63/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1033 - sparse_categorical_accuracy: 0.9682 - val_loss: 0.0140 - val_sparse_categorical_accuracy: 0.9973
# Epoch 64/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.0289 - val_sparse_categorical_accuracy: 0.9947
# Epoch 65/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.1092 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.0260 - val_sparse_categorical_accuracy: 0.9973
# Epoch 66/80
# 47/47 [==============================] - 0s 10ms/step - loss: 0.0738 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.0365 - val_sparse_categorical_accuracy: 0.9947

# %%
import pandas as pd
def plot_learning_curves(history):
    df = pd.DataFrame(history.history)
    df.plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
    
plot_learning_curves(history)

# %%
out = model.predict(np.expand_dims(X[5], 0))
plt.imshow(X[5], cmap=plt.get_cmap('gray'))
out
# Out:
# array([[3.9239786e-10, 2.5999264e-10, 4.4518832e-13, 5.6383578e-12,
#         2.8517350e-08, 5.9767087e-12, 3.1428360e-09, 1.0743257e-08,
#         1.0000000e+00]], dtype=float32)

# %%
model.save('model.h5')
